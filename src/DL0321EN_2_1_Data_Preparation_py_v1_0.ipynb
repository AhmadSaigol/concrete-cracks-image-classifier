# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width = 400> </a>
#
# <h1 align=center><font size = 5>Data Preparation</font></h1>

# %% [markdown]
# ## Objective

# %% [markdown]
# In this lab, you will learn how to load images and manipulate them for training using Keras ImageDataGenerator.

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1.  <a href="#item21">Download Data</a>
# 2.  <a href="#item22">Import Libraries and Packages</a>
# 3.  <a href="#item23">Construct an ImageDataGenerator Instance</a>
# 4.  <a href="#item24">Visualize Batches of Images</a>
# 5.  <a href="#item25">Questions</a>
#     </font>
#
#
# </div>

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# <a id='item21'></a>

# %% [markdown]
# ## Download Data

# %% [markdown]
# For your convenience, I have placed the data on a server which you can retrieve easily using the **wget** command. So let's run the following line of code to get the data. Given the large size of the image dataset, it might take some time depending on your internet speed.

# %%
## get the data
# !wget -P ../dataset/week2 https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/concrete_data_week2.zip
# Out:
# --2021-12-07 15:22:56--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/concrete_data_week2.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 260502910 (248M) [application/zip]
# Saving to: ‘../dataset/week2/concrete_data_week2.zip’
#
# concrete_data_week2 100%[===================>] 248.43M  39.0MB/s    in 6.8s
#
# 2021-12-07 15:23:03 (36.4 MB/s) - ‘../dataset/week2/concrete_data_week2.zip’ saved [260502910/260502910]

# %% [markdown]
# And now if you check the left directory pane, you should see the zipped file _concrete_data_week2.zip_ appear. So, let's go ahead and unzip the file to access the images. Given the large number of images in the dataset, this might take a couple of minutes, so please be patient, and wait until the code finishes running.

# %%
# !unzip ../dataset/week2/concrete_data_week2.zip -d ../dataset/week2
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05723.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15530.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15530.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03352.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03352.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13141.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13141.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10448.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10448.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08207.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08207.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07134.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07134.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18014.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18014.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17327.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17327.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01545.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01545.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16039.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16039.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09119.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09119.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11756.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11756.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00883.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00883.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11030.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11030.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01223.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01223.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18772.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18772.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17441.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17441.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08561.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08561.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07652.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07652.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16987.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16987.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13627.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13627.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14148.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14148.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03434.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03434.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15256.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15256.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05045.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05045.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12539.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12539.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13633.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13633.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03420.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03420.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15242.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15242.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05051.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05051.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11024.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11024.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06558.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06558.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19478.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19478.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01237.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01237.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00129.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00129.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18766.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18766.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17455.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17455.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08575.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08575.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16993.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16993.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07646.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07646.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08213.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08213.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07120.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07120.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18000.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18000.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17333.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17333.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01551.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01551.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00897.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00897.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11742.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11742.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05737.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05737.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15524.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15524.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02058.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02058.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03346.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03346.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04429.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04429.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13155.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13155.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07108.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07108.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10474.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10474.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18028.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18028.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00667.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00667.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16005.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16005.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01579.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01579.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19336.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19336.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06216.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06216.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09125.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09125.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12263.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12263.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02070.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02070.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14612.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14612.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04401.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04401.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04367.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04367.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03408.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03408.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14174.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14174.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02716.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02716.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12505.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12505.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05079.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05079.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06570.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06570.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18996.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18996.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09643.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09643.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16763.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16763.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19450.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19450.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00101.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00101.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10312.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10312.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06564.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06564.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11018.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11018.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09657.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09657.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18982.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18982.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16777.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16777.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19444.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19444.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17469.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17469.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00115.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00115.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08549.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08549.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10306.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10306.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04373.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04373.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14160.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14160.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02702.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02702.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12511.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12511.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12277.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12277.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02064.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02064.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15518.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15518.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14606.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14606.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13169.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13169.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04415.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04415.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10460.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10460.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00673.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00673.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16011.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16011.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19322.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19322.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06202.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06202.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09131.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09131.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01586.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01586.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11795.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11795.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00840.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00840.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00698.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00698.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05938.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05938.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03391.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03391.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13182.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13182.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14835.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14835.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15295.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15295.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05086.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05086.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04398.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04398.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02931.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02931.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09864.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09864.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17482.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17482.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07691.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07691.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16944.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16944.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18969.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18969.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07849.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07849.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09870.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09870.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17496.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17496.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16950.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16950.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07685.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07685.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16788.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16788.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15281.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15281.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13828.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13828.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05092.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05092.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02925.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02925.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03385.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03385.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13196.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13196.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14821.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14821.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12288.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12288.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01592.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01592.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00854.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00854.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11781.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11781.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11959.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11959.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05904.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05904.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14809.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14809.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11971.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11971.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09858.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09858.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16978.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16978.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18955.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18955.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09680.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09680.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07875.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07875.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19493.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19493.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13800.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13800.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13814.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13814.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02919.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02919.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18799.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18799.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09694.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09694.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18941.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18941.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07861.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07861.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19487.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19487.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00868.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00868.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11965.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11965.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05910.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05910.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05247.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05247.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02528.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02528.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15054.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15054.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03636.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03636.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13425.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13425.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04159.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04159.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07450.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07450.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08763.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08763.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17643.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17643.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06996.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06996.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18570.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18570.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01021.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01021.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11232.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11232.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06028.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06028.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11554.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11554.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19108.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19108.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01747.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01747.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10892.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10892.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17125.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17125.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00459.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00459.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18216.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18216.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07336.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07336.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08005.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08005.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13343.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13343.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03150.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03150.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15732.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15732.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05521.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05521.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13357.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13357.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03144.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03144.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14438.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14438.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15726.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15726.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12049.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12049.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05535.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05535.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11540.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11540.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10886.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10886.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01753.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01753.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17131.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17131.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18202.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18202.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07322.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07322.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08011.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08011.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07444.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07444.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10138.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10138.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08777.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08777.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06982.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06982.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17657.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17657.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18564.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18564.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16549.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16549.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01035.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01035.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09469.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09469.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11226.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11226.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05253.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05253.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15040.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15040.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03622.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03622.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13431.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13431.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10110.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10110.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00303.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00303.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08987.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08987.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19652.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19652.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16561.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16561.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09441.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09441.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06772.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06772.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12707.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12707.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15068.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15068.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02514.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02514.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14376.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14376.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04165.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04165.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13419.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13419.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04603.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04603.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14410.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14410.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02272.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02272.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12061.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12061.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11568.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11568.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09327.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09327.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06014.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06014.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19134.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19134.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16207.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16207.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00465.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00465.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17119.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17119.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08039.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08039.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10676.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10676.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09333.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09333.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06000.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06000.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19120.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19120.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16213.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16213.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00471.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00471.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10662.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10662.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04617.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04617.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14404.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14404.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03178.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03178.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02266.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02266.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05509.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05509.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12075.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12075.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12713.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12713.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02500.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02500.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14362.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14362.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04171.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04171.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10104.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10104.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07478.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07478.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18558.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18558.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00317.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00317.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01009.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01009.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19646.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19646.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08993.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08993.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16575.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16575.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09455.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09455.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06766.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06766.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08978.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08978.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17858.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17858.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07493.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07493.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19875.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19875.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17680.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17680.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06955.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06955.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12920.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12920.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14389.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14389.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05284.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05284.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15097.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15097.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04824.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04824.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13380.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13380.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15929.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15929.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03193.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03193.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10689.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10689.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11597.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11597.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01784.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01784.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10851.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10851.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01948.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01948.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11583.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11583.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10845.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10845.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01790.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01790.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02299.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02299.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04830.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04830.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13394.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13394.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03187.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03187.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12934.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12934.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03839.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03839.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05290.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05290.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15083.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15083.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06799.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06799.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07487.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07487.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19861.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19861.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06941.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06941.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17694.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17694.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03811.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03811.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08944.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08944.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19691.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19691.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09482.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09482.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17864.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17864.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19849.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19849.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06969.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06969.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01960.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01960.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04818.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04818.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15915.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15915.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15901.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15901.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01974.jpg
# ...
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06572.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06572.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09641.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09641.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18994.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18994.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12507.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12507.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02714.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02714.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15268.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15268.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14176.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14176.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13619.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13619.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04365.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04365.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04403.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04403.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14610.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14610.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02072.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02072.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12261.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12261.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06214.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06214.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11768.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11768.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09127.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09127.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16007.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16007.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19334.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19334.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17319.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17319.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00665.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00665.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08239.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08239.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10476.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10476.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06200.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06200.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09133.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09133.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16013.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16013.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19320.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19320.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00671.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00671.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10462.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10462.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04417.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04417.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03378.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03378.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14604.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14604.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02066.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02066.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12275.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12275.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05709.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05709.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12513.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12513.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02700.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02700.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14162.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14162.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04371.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04371.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07678.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07678.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10304.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10304.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18758.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18758.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00117.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00117.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16775.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16775.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01209.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01209.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19446.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19446.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06566.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06566.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18980.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18980.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09655.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09655.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05047.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05047.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15254.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15254.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/02728.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._02728.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03436.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03436.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/04359.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._04359.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13625.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13625.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08563.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08563.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16985.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16985.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07650.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07650.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18770.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18770.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17443.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17443.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01221.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01221.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07888.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07888.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11032.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11032.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00881.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00881.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11754.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11754.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/06228.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._06228.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/19308.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._19308.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01547.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01547.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00659.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00659.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18016.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18016.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17325.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17325.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08205.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08205.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07136.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07136.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13143.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13143.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03350.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03350.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15532.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15532.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05721.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05721.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13157.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13157.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/14638.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._14638.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03344.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03344.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15526.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15526.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05735.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05735.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/12249.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._12249.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11740.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11740.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/00895.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._00895.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01553.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01553.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18002.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18002.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11998.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11998.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17331.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17331.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08211.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08211.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07122.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07122.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/10338.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._10338.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/08577.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._08577.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/07644.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._07644.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16991.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16991.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/18764.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._18764.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/17457.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._17457.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/01235.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._01235.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/16749.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._16749.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/09669.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._09669.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/11026.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._11026.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/05053.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._05053.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/15240.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._15240.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/03422.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._03422.jpg
#   inflating: ../dataset/week2/concrete_data_week2/Negative/13631.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/Negative/._13631.jpg
#   inflating: ../dataset/week2/__MACOSX/concrete_data_week2/._Negative

# %% [markdown]
# Now, you should see the folder _concrete_data_week2_ appear in the left pane. If you open this folder by double-clicking on it, you will find that it contains two folders: _Positive_ and _Negative_. These are the same folders that we saw in the lab in the previous module of this course, where _Negative_ is the negative class and it represents the concrete images with no cracks. _Positive_ on the other hand is the positive class and represents the concrete images with cracks.

# %% [markdown]
# **Important Note**: There are thousands and thousands of images in each folder, so please don't attempt to double click on the _Negative_ and _Positive_ folders. This may consume all of your memory and you may end up with a **50\*** error. So please **DO NOT DO IT**.

# %% [markdown]
# <a id='item22'></a>

# %% [markdown]
# ## Import Libraries and Packages

# %% [markdown]
# Before we proceed, let's import the libraries and packages that we will need to complete the rest of this lab.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import keras
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# You can check the content of <code>./concrete_data_week2</code> by running the following:

# %%
# !ls ../datset/week2/concrete_data_week2
# Out:
# ls: cannot access '../datset/week2/concrete_data_week2': No such file or directory

# %% [markdown]
# or the following:

# %%
os.listdir('../dataset/week2/concrete_data_week2')
# Out:
# ['Positive', '.DS_Store', 'Negative']

# %% [markdown]
# <a id='item23'></a>

# %% [markdown]
# ## Construct an ImageDataGenerator Instance

# %% [markdown]
# In this section, you will learn how to define a Keras ImageDataGenerator instance and use it to load and manipulate data for building a deep learning model.

# %% [markdown]
# Before we proceed, let's define a variable that represents the path to the folder containing our data which is <code>concrete_data_week2</code> in this case.

# %%
dataset_dir = '../dataset/week2/concrete_data_week2'

# %% [markdown]
# Keras ImageDataGenerator requires images be arranged in a certain folder hierarchy, where the main directory would contain folders equal to the number of classes in your problem. Since in this case we are trying to build a classifier of two classes, then our main directory, which is <code>concrete_data_week2</code>, should contain two folders, one for each class. This has already been done for you as the negative images are in one folder and the positive images are in another folder.

# %% [markdown]
# Let's go ahead and define an instance of the Keras ImageDataGenerator.

# %% [markdown]
# #### Standard ImageDataGenerator

# %% [markdown]
# You can define a standard one like this, where you are simply using the ImageDataGenerator to train your model in batches.

# %%
# instantiate your image data generator
data_generator = ImageDataGenerator()

# %% [markdown]
# Next, you use the <code>flow_from_directory</code> methods to loop through the images in batches. In this method, you pass the directory where the images reside, the size of each batch, _batch_size_, and since batches are sampled randomly, then you can also specify a random seed, _seed_, if you would like to reproduce the batch sampling. In case you would like to resize your images, then you can using the _target_size_ argument to accomplish that.

# %%
image_generator = data_generator.flow_from_directory(
    dataset_dir,
    batch_size=4,
    class_mode='categorical',
    seed=24
    )
# Out:
# Found 40000 images belonging to 2 classes.

# %% [markdown]
# What is great about this method, is it prints a summary of it found in the directory passed. Here, it found 40,000 images in total belonging to 2 classes.

# %% [markdown]
# Now, to access the batches, you use the <code>next</code> method as follows:

# %%
first_batch = image_generator.next()
first_batch
# Out:
# (array([[[[151., 149., 150.],
#           [153., 151., 152.],
#           [155., 153., 154.],
#           ...,
#           [153., 149., 148.],
#           [153., 149., 148.],
#           [153., 149., 148.]],
#
#          [[152., 150., 151.],
#           [154., 152., 153.],
#           [156., 154., 155.],
#           ...,
#           [154., 150., 149.],
#           [154., 150., 149.],
#           [154., 150., 149.]],
#
#          [[153., 151., 152.],
#           [155., 153., 154.],
#           [156., 154., 155.],
#           ...,
#           [156., 152., 151.],
#           [156., 152., 151.],
#           [156., 152., 151.]],
#
#          ...,
#
#          [[142., 140., 143.],
#           [142., 140., 143.],
#           [142., 140., 143.],
#           ...,
#           [139., 135., 136.],
#           [142., 138., 139.],
#           [145., 141., 142.]],
#
#          [[142., 140., 143.],
#           [142., 140., 143.],
#           [142., 140., 143.],
#           ...,
#           [140., 136., 137.],
#           [142., 138., 139.],
#           [146., 142., 143.]],
#
#          [[142., 140., 143.],
#           [142., 140., 143.],
#           [142., 140., 143.],
#           ...,
#           [141., 137., 138.],
#           [144., 140., 141.],
#           [147., 143., 144.]]],
#
#
#         [[[189., 186., 181.],
#           [191., 188., 183.],
#           [194., 191., 186.],
#           ...,
#           [186., 185., 181.],
#           [184., 183., 179.],
#           [183., 182., 178.]],
#
#          [[188., 185., 180.],
#           [190., 187., 182.],
#           [194., 191., 186.],
#           ...,
#           [186., 185., 181.],
#           [185., 184., 180.],
#           [184., 183., 179.]],
#
#          [[186., 183., 178.],
#           [189., 186., 181.],
#           [193., 190., 185.],
#           ...,
#           [186., 185., 181.],
#           [185., 184., 180.],
#           [185., 184., 180.]],
#
#          ...,
#
#          [[188., 185., 180.],
#           [187., 184., 179.],
#           [186., 183., 178.],
#           ...,
#           [170., 170., 162.],
#           [170., 170., 162.],
#           [171., 171., 163.]],
#
#          [[188., 185., 180.],
#           [187., 184., 179.],
#           [186., 183., 178.],
#           ...,
#           [171., 171., 163.],
#           [171., 171., 163.],
#           [172., 172., 164.]],
#
#          [[188., 185., 180.],
#           [187., 184., 179.],
#           [186., 183., 178.],
#           ...,
#           [179., 179., 171.],
#           [179., 179., 171.],
#           [179., 179., 171.]]],
#
#
#         [[[181., 173., 162.],
#           [176., 168., 157.],
#           [168., 160., 149.],
#           ...,
#           [171., 167., 156.],
#           [170., 166., 155.],
#           [169., 165., 154.]],
#
#          [[180., 172., 161.],
#           [176., 168., 157.],
#           [170., 162., 151.],
#           ...,
#           [172., 168., 157.],
#           [171., 167., 156.],
#           [170., 166., 155.]],
#
#          [[179., 171., 160.],
#           [176., 168., 157.],
#           [171., 163., 152.],
#           ...,
#           [174., 170., 159.],
#           [173., 169., 158.],
#           [172., 168., 157.]],
#
#          ...,
#
#          [[175., 171., 160.],
#           [178., 174., 163.],
#           [182., 178., 167.],
#           ...,
#           [173., 168., 162.],
#           [173., 168., 162.],
#           [173., 168., 162.]],
#
#          [[175., 171., 160.],
#           [178., 174., 163.],
#           [182., 178., 167.],
#           ...,
#           [175., 170., 164.],
#           [175., 170., 164.],
#           [175., 170., 164.]],
#
#          [[175., 171., 160.],
#           [178., 174., 163.],
#           [182., 178., 167.],
#           ...,
#           [177., 172., 166.],
#           [177., 172., 166.],
#           [177., 172., 166.]]],
#
#
#         [[[150., 149., 147.],
#           [148., 147., 145.],
#           [146., 145., 143.],
#           ...,
#           [199., 195., 192.],
#           [194., 190., 187.],
#           [189., 185., 182.]],
#
#          [[153., 152., 150.],
#           [152., 151., 149.],
#           [151., 150., 148.],
#           ...,
#           [196., 192., 189.],
#           [192., 188., 185.],
#           [186., 182., 179.]],
#
#          [[153., 152., 150.],
#           [155., 154., 152.],
#           [156., 155., 153.],
#           ...,
#           [192., 188., 185.],
#           [188., 184., 181.],
#           [182., 178., 175.]],
#
#          ...,
#
#          [[179., 175., 174.],
#           [180., 176., 175.],
#           [181., 177., 176.],
#           ...,
#           [174., 170., 167.],
#           [173., 169., 166.],
#           [173., 169., 166.]],
#
#          [[180., 176., 175.],
#           [180., 176., 175.],
#           [180., 176., 175.],
#           ...,
#           [176., 172., 169.],
#           [175., 171., 168.],
#           [173., 169., 166.]],
#
#          [[182., 178., 177.],
#           [181., 177., 176.],
#           [179., 175., 174.],
#           ...,
#           [180., 176., 173.],
#           [177., 173., 170.],
#           [174., 170., 167.]]]], dtype=float32), array([[1., 0.],
#         [0., 1.],
#         [1., 0.],
#         [0., 1.]], dtype=float32))

# %% [markdown]
# As you can see, this returned the images along with their labels. Therefore, the following returns the images only,

# %%
first_batch_images = image_generator.next()[0]
first_batch_images
# Out:
# array([[[[172., 174., 169.],
#          [176., 178., 173.],
#          [181., 183., 178.],
#          ...,
#          [157., 159., 154.],
#          [156., 158., 153.],
#          [154., 156., 151.]],
#
#         [[170., 172., 167.],
#          [172., 174., 169.],
#          [174., 176., 171.],
#          ...,
#          [155., 157., 152.],
#          [154., 156., 151.],
#          [153., 155., 150.]],
#
#         [[169., 171., 166.],
#          [167., 169., 164.],
#          [166., 168., 163.],
#          ...,
#          [152., 154., 149.],
#          [152., 154., 149.],
#          [151., 153., 148.]],
#
#         ...,
#
#         [[153., 154., 148.],
#          [155., 156., 150.],
#          [158., 159., 153.],
#          ...,
#          [143., 144., 138.],
#          [144., 145., 139.],
#          [145., 146., 140.]],
#
#         [[147., 148., 142.],
#          [150., 151., 145.],
#          [153., 154., 148.],
#          ...,
#          [142., 143., 137.],
#          [143., 144., 138.],
#          [144., 145., 139.]],
#
#         [[141., 142., 136.],
#          [145., 146., 140.],
#          [149., 150., 144.],
#          ...,
#          [141., 142., 136.],
#          [142., 143., 137.],
#          [143., 144., 138.]]],
#
#
#        [[[183., 180., 173.],
#          [173., 170., 163.],
#          [171., 168., 161.],
#          ...,
#          [175., 172., 165.],
#          [175., 172., 165.],
#          [174., 171., 164.]],
#
#         [[178., 175., 168.],
#          [173., 170., 163.],
#          [174., 171., 164.],
#          ...,
#          [171., 168., 161.],
#          [171., 168., 161.],
#          [170., 167., 160.]],
#
#         [[169., 166., 159.],
#          [169., 166., 159.],
#          [175., 172., 165.],
#          ...,
#          [166., 163., 156.],
#          [166., 163., 156.],
#          [164., 161., 154.]],
#
#         ...,
#
#         [[188., 185., 178.],
#          [186., 183., 176.],
#          [183., 180., 173.],
#          ...,
#          [150., 149., 144.],
#          [147., 146., 141.],
#          [144., 143., 138.]],
#
#         [[186., 183., 176.],
#          [184., 181., 174.],
#          [181., 178., 171.],
#          ...,
#          [150., 149., 144.],
#          [147., 146., 141.],
#          [144., 143., 138.]],
#
#         [[184., 181., 174.],
#          [182., 179., 172.],
#          [178., 175., 168.],
#          ...,
#          [150., 149., 144.],
#          [148., 147., 142.],
#          [145., 144., 139.]]],
#
#
#        [[[165., 160., 154.],
#          [163., 158., 152.],
#          [160., 155., 149.],
#          ...,
#          [155., 150., 146.],
#          [156., 151., 147.],
#          [157., 152., 148.]],
#
#         [[164., 159., 153.],
#          [162., 157., 151.],
#          [160., 155., 149.],
#          ...,
#          [157., 152., 148.],
#          [158., 153., 149.],
#          [159., 154., 150.]],
#
#         [[163., 158., 152.],
#          [162., 157., 151.],
#          [161., 156., 150.],
#          ...,
#          [160., 155., 151.],
#          [160., 155., 151.],
#          [161., 156., 152.]],
#
#         ...,
#
#         [[159., 154., 148.],
#          [164., 159., 153.],
#          [169., 164., 158.],
#          ...,
#          [145., 140., 134.],
#          [145., 140., 134.],
#          [145., 140., 134.]],
#
#         [[158., 153., 147.],
#          [164., 159., 153.],
#          [169., 164., 158.],
#          ...,
#          [146., 141., 135.],
#          [146., 141., 135.],
#          [146., 141., 135.]],
#
#         [[158., 153., 147.],
#          [163., 158., 152.],
#          [169., 164., 158.],
#          ...,
#          [147., 142., 136.],
#          [147., 142., 136.],
#          [147., 142., 136.]]],
#
#
#        [[[142., 133., 124.],
#          [144., 135., 126.],
#          [147., 138., 129.],
#          ...,
#          [176., 172., 161.],
#          [178., 174., 163.],
#          [181., 177., 166.]],
#
#         [[140., 131., 122.],
#          [144., 135., 126.],
#          [150., 141., 132.],
#          ...,
#          [179., 175., 164.],
#          [179., 175., 164.],
#          [180., 176., 165.]],
#
#         [[141., 132., 123.],
#          [147., 138., 129.],
#          [155., 146., 137.],
#          ...,
#          [176., 172., 161.],
#          [175., 171., 160.],
#          [174., 170., 159.]],
#
#         ...,
#
#         [[170., 166., 154.],
#          [177., 173., 161.],
#          [183., 179., 167.],
#          ...,
#          [171., 168., 161.],
#          [172., 169., 162.],
#          [173., 170., 163.]],
#
#         [[171., 167., 155.],
#          [178., 174., 162.],
#          [183., 179., 167.],
#          ...,
#          [171., 168., 161.],
#          [172., 169., 162.],
#          [173., 170., 163.]],
#
#         [[173., 169., 157.],
#          [179., 175., 163.],
#          [182., 178., 166.],
#          ...,
#          [172., 169., 162.],
#          [172., 169., 162.],
#          [173., 170., 163.]]]], dtype=float32)

# %% [markdown]
# and the following returns the labels only.

# %%
first_batch_labels = image_generator.next()[1]
first_batch_labels
# Out:
# array([[1., 0.],
#        [0., 1.],
#        [0., 1.],
#        [0., 1.]], dtype=float32)

# %% [markdown]
# #### Custom ImageDataGenerator

# %% [markdown]
# You can also specify some transforms, like scaling, rotations, and flips, that you would like applied to the images when you define an ImageDataGenerator object. Say you want to normalize your images, then you can define your ImageDataGenerator instance as follows:

# %%
# instantiate your image data generator
data_generator = ImageDataGenerator(
    rescale=1./255
)

# %% [markdown]
# And then you proceed with defining your _image_generator_ using the _flow_from_directory_ method, just like before.

# %%
image_generator = data_generator.flow_from_directory(
    dataset_dir,
    batch_size=4,
    class_mode='categorical',
    seed=24
    )
# Out:
# Found 40000 images belonging to 2 classes.

# %% [markdown]
# However, now we explore the first batch using the _next_ method,

# %%
first_batch = image_generator.next()
first_batch
# Out:
# (array([[[[0.5921569 , 0.58431375, 0.5882353 ],
#           [0.6       , 0.5921569 , 0.59607846],
#           [0.60784316, 0.6       , 0.6039216 ],
#           ...,
#           [0.6       , 0.58431375, 0.5803922 ],
#           [0.6       , 0.58431375, 0.5803922 ],
#           [0.6       , 0.58431375, 0.5803922 ]],
#
#          [[0.59607846, 0.5882353 , 0.5921569 ],
#           [0.6039216 , 0.59607846, 0.6       ],
#           [0.6117647 , 0.6039216 , 0.60784316],
#           ...,
#           [0.6039216 , 0.5882353 , 0.58431375],
#           [0.6039216 , 0.5882353 , 0.58431375],
#           [0.6039216 , 0.5882353 , 0.58431375]],
#
#          [[0.6       , 0.5921569 , 0.59607846],
#           [0.60784316, 0.6       , 0.6039216 ],
#           [0.6117647 , 0.6039216 , 0.60784316],
#           ...,
#           [0.6117647 , 0.59607846, 0.5921569 ],
#           [0.6117647 , 0.59607846, 0.5921569 ],
#           [0.6117647 , 0.59607846, 0.5921569 ]],
#
#          ...,
#
#          [[0.5568628 , 0.54901963, 0.56078434],
#           [0.5568628 , 0.54901963, 0.56078434],
#           [0.5568628 , 0.54901963, 0.56078434],
#           ...,
#           [0.54509807, 0.5294118 , 0.53333336],
#           [0.5568628 , 0.5411765 , 0.54509807],
#           [0.5686275 , 0.5529412 , 0.5568628 ]],
#
#          [[0.5568628 , 0.54901963, 0.56078434],
#           [0.5568628 , 0.54901963, 0.56078434],
#           [0.5568628 , 0.54901963, 0.56078434],
#           ...,
#           [0.54901963, 0.53333336, 0.5372549 ],
#           [0.5568628 , 0.5411765 , 0.54509807],
#           [0.57254905, 0.5568628 , 0.56078434]],
#
#          [[0.5568628 , 0.54901963, 0.56078434],
#           [0.5568628 , 0.54901963, 0.56078434],
#           [0.5568628 , 0.54901963, 0.56078434],
#           ...,
#           [0.5529412 , 0.5372549 , 0.5411765 ],
#           [0.5647059 , 0.54901963, 0.5529412 ],
#           [0.5764706 , 0.56078434, 0.5647059 ]]],
#
#
#         [[[0.7411765 , 0.7294118 , 0.70980394],
#           [0.7490196 , 0.7372549 , 0.7176471 ],
#           [0.7607844 , 0.7490196 , 0.7294118 ],
#           ...,
#           [0.7294118 , 0.7254902 , 0.70980394],
#           [0.72156864, 0.7176471 , 0.7019608 ],
#           [0.7176471 , 0.7137255 , 0.69803923]],
#
#          [[0.7372549 , 0.7254902 , 0.7058824 ],
#           [0.74509805, 0.73333335, 0.7137255 ],
#           [0.7607844 , 0.7490196 , 0.7294118 ],
#           ...,
#           [0.7294118 , 0.7254902 , 0.70980394],
#           [0.7254902 , 0.72156864, 0.7058824 ],
#           [0.72156864, 0.7176471 , 0.7019608 ]],
#
#          [[0.7294118 , 0.7176471 , 0.69803923],
#           [0.7411765 , 0.7294118 , 0.70980394],
#           [0.7568628 , 0.74509805, 0.7254902 ],
#           ...,
#           [0.7294118 , 0.7254902 , 0.70980394],
#           [0.7254902 , 0.72156864, 0.7058824 ],
#           [0.7254902 , 0.72156864, 0.7058824 ]],
#
#          ...,
#
#          [[0.7372549 , 0.7254902 , 0.7058824 ],
#           [0.73333335, 0.72156864, 0.7019608 ],
#           [0.7294118 , 0.7176471 , 0.69803923],
#           ...,
#           [0.6666667 , 0.6666667 , 0.63529414],
#           [0.6666667 , 0.6666667 , 0.63529414],
#           [0.67058825, 0.67058825, 0.6392157 ]],
#
#          [[0.7372549 , 0.7254902 , 0.7058824 ],
#           [0.73333335, 0.72156864, 0.7019608 ],
#           [0.7294118 , 0.7176471 , 0.69803923],
#           ...,
#           [0.67058825, 0.67058825, 0.6392157 ],
#           [0.67058825, 0.67058825, 0.6392157 ],
#           [0.6745098 , 0.6745098 , 0.6431373 ]],
#
#          [[0.7372549 , 0.7254902 , 0.7058824 ],
#           [0.73333335, 0.72156864, 0.7019608 ],
#           [0.7294118 , 0.7176471 , 0.69803923],
#           ...,
#           [0.7019608 , 0.7019608 , 0.67058825],
#           [0.7019608 , 0.7019608 , 0.67058825],
#           [0.7019608 , 0.7019608 , 0.67058825]]],
#
#
#         [[[0.70980394, 0.6784314 , 0.63529414],
#           [0.6901961 , 0.65882355, 0.6156863 ],
#           [0.65882355, 0.627451  , 0.58431375],
#           ...,
#           [0.67058825, 0.654902  , 0.6117647 ],
#           [0.6666667 , 0.6509804 , 0.60784316],
#           [0.6627451 , 0.64705884, 0.6039216 ]],
#
#          [[0.7058824 , 0.6745098 , 0.6313726 ],
#           [0.6901961 , 0.65882355, 0.6156863 ],
#           [0.6666667 , 0.63529414, 0.5921569 ],
#           ...,
#           [0.6745098 , 0.65882355, 0.6156863 ],
#           [0.67058825, 0.654902  , 0.6117647 ],
#           [0.6666667 , 0.6509804 , 0.60784316]],
#
#          [[0.7019608 , 0.67058825, 0.627451  ],
#           [0.6901961 , 0.65882355, 0.6156863 ],
#           [0.67058825, 0.6392157 , 0.59607846],
#           ...,
#           [0.68235296, 0.6666667 , 0.62352943],
#           [0.6784314 , 0.6627451 , 0.61960787],
#           [0.6745098 , 0.65882355, 0.6156863 ]],
#
#          ...,
#
#          [[0.6862745 , 0.67058825, 0.627451  ],
#           [0.69803923, 0.68235296, 0.6392157 ],
#           [0.7137255 , 0.69803923, 0.654902  ],
#           ...,
#           [0.6784314 , 0.65882355, 0.63529414],
#           [0.6784314 , 0.65882355, 0.63529414],
#           [0.6784314 , 0.65882355, 0.63529414]],
#
#          [[0.6862745 , 0.67058825, 0.627451  ],
#           [0.69803923, 0.68235296, 0.6392157 ],
#           [0.7137255 , 0.69803923, 0.654902  ],
#           ...,
#           [0.6862745 , 0.6666667 , 0.6431373 ],
#           [0.6862745 , 0.6666667 , 0.6431373 ],
#           [0.6862745 , 0.6666667 , 0.6431373 ]],
#
#          [[0.6862745 , 0.67058825, 0.627451  ],
#           [0.69803923, 0.68235296, 0.6392157 ],
#           [0.7137255 , 0.69803923, 0.654902  ],
#           ...,
#           [0.69411767, 0.6745098 , 0.6509804 ],
#           [0.69411767, 0.6745098 , 0.6509804 ],
#           [0.69411767, 0.6745098 , 0.6509804 ]]],
#
#
#         [[[0.5882353 , 0.58431375, 0.5764706 ],
#           [0.5803922 , 0.5764706 , 0.5686275 ],
#           [0.57254905, 0.5686275 , 0.56078434],
#           ...,
#           [0.7803922 , 0.76470596, 0.75294125],
#           [0.7607844 , 0.74509805, 0.73333335],
#           [0.7411765 , 0.7254902 , 0.7137255 ]],
#
#          [[0.6       , 0.59607846, 0.5882353 ],
#           [0.59607846, 0.5921569 , 0.58431375],
#           [0.5921569 , 0.5882353 , 0.5803922 ],
#           ...,
#           [0.7686275 , 0.75294125, 0.7411765 ],
#           [0.75294125, 0.7372549 , 0.7254902 ],
#           [0.7294118 , 0.7137255 , 0.7019608 ]],
#
#          [[0.6       , 0.59607846, 0.5882353 ],
#           [0.60784316, 0.6039216 , 0.59607846],
#           [0.6117647 , 0.60784316, 0.6       ],
#           ...,
#           [0.75294125, 0.7372549 , 0.7254902 ],
#           [0.7372549 , 0.72156864, 0.70980394],
#           [0.7137255 , 0.69803923, 0.6862745 ]],
#
#          ...,
#
#          [[0.7019608 , 0.6862745 , 0.68235296],
#           [0.7058824 , 0.6901961 , 0.6862745 ],
#           [0.70980394, 0.69411767, 0.6901961 ],
#           ...,
#           [0.68235296, 0.6666667 , 0.654902  ],
#           [0.6784314 , 0.6627451 , 0.6509804 ],
#           [0.6784314 , 0.6627451 , 0.6509804 ]],
#
#          [[0.7058824 , 0.6901961 , 0.6862745 ],
#           [0.7058824 , 0.6901961 , 0.6862745 ],
#           [0.7058824 , 0.6901961 , 0.6862745 ],
#           ...,
#           [0.6901961 , 0.6745098 , 0.6627451 ],
#           [0.6862745 , 0.67058825, 0.65882355],
#           [0.6784314 , 0.6627451 , 0.6509804 ]],
#
#          [[0.7137255 , 0.69803923, 0.69411767],
#           [0.70980394, 0.69411767, 0.6901961 ],
#           [0.7019608 , 0.6862745 , 0.68235296],
#           ...,
#           [0.7058824 , 0.6901961 , 0.6784314 ],
#           [0.69411767, 0.6784314 , 0.6666667 ],
#           [0.68235296, 0.6666667 , 0.654902  ]]]], dtype=float32),
#  array([[1., 0.],
#         [0., 1.],
#         [1., 0.],
#         [0., 1.]], dtype=float32))

# %% [markdown]
# we find that the values are not integer values anymore, but scaled resolution since the original number are divided by 255.

# %% [markdown]
# You can learn more about the Keras ImageDataGeneration class [here](https://keras.io/preprocessing/image?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork-20647850&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork-20647850&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).

# %% [markdown]
# <a id='item24'></a>

# %% [markdown]
# ## Visualize Batches of Images

# %% [markdown]
# Let write some code to visualize a batch. We will use subplots in order to make visualizing the images easier.

# %% [markdown]
# Recall that we can access our batch images as follows:
#
# <code>first_batch_images = image_generator.next()[0] # first batch</code>
#
# <code>second_batch_images = image_generator.next()[0] # second batch</code>
#
# and so on.

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(20, 10)) # define your figure and axes

ind = 0
for ax1 in axs:
    for ax2 in ax1: 
        #image_data = first_batch_images[ind]
        image_data = first_batch_images[ind].astype(np.uint8)
        ax2.imshow(image_data)
        ind += 1

fig.suptitle('First Batch of Concrete Images') 
plt.show()

# %% [markdown]
# Remember that batches are sampled randomly from the data. In our first batch, we ended up with two negative image and two positive images.

# %% [markdown]
# **Important Note**: Because of a bug with the imshow function in Matplotlib, if you are plotting the unscaled RGB images, then the **image_data** in the code above would be like this:
#
# image_data = first_batch_images[ind].astype(np.uint8)
#
# where the image_data is cast to uint8 before you call the <code>imshow</code> function.

# %% [markdown]
# <a id='item25'></a>

# %% [markdown]
# ## Questions

# %% [markdown]
# ### Question: Create a plot to visualize the images in the third batch.

# %%
## You can use this cell to type your code to answer the above question
dirr='../dataset/week2/concrete_data_week2'
DG = ImageDataGenerator()
IG = DG.flow_from_directory(
dirr,
batch_size=4,
class_mode='categorical',
seed=24
)
for i in range(3):
    batch=IG.next()[0]
fig, axs =plt.subplots(nrows=2, ncols=2, figsize=(20,10))
index=0
for ax3 in axs:
    for ax4 in ax3:
        im = batch[index].astype(np.uint8)
        ax4.imshow(im)
        index+=1
fig.suptitle("third batch")
plt.show()
# Out:
# Found 40000 images belonging to 2 classes.

# %% [markdown]
# ### Question: How many images from each class are in the fourth batch?

# %%
## You can use this cell to type your code to answer the above question

len(IG.next()[0])
# Out:
# 4

# %% [markdown]
# ### Question: Create a plot to visualize the second image in the fifth batch.

# %%
## You can use this cell to type your code to answer the above question
fifth_batch=IG.next()
fi_image=fifth_batch[0]
plt.imshow(fi_image[1].astype(np.uint8))

# %% [markdown]
# ### Question: How many images from each class are in the fifth batch?

# %%
## You can use this cell to type your code to answer the above question
len(fifth_batch)
# Out:
# 2

# %% [markdown]
# Make sure to answer the above questions as the quiz in this module is heavily based on them.

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by Alex Aklson. I hope you found this lab interesting and educational.

# %% [markdown]
# This notebook is part of a course on **Coursera** called _AI Capstone Project with Deep Learning_. If you accessed this notebook outside the course, you can take this course online by clicking [here](https://cocl.us/DL0321EN_Coursera_Week2_LAB1).

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                                          |
# | ----------------- | ------- | ---------- | ----------------------------------------------------------- |
# | 2020-09-18        | 2.0     | Shubham    | Migrated Lab to Markdown and added to course repo in GitLab |

# %% [markdown]
# <hr>
#
# Copyright © 2020 [IBM Developer Skills Network](https://cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork-20647850&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork-20647850&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork-20647850&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork-20647850&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork-20647850&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork-20647850&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
